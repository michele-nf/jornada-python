# %% [markdown]
# # Lista de Estrutura Sequencial

# %% [markdown]
# #### 1. Faça um Programa que mostre a mensagem (print) "Alo mundo" na tela.

# %%
print("Alô, Mundo!")
# Out:
# Alô, Mundo!

# %% [markdown]
# #### 2. Faça um Programa que peça um número (input) e então mostre a mensagem: "O número informado foi [número]."

# %%
numero = input("Informe o número: ")

print(f"O número informado foi {numero}.")
# Out:
# O número informado foi 25.

# %% [markdown]
# #### 3. Faça um Programa que peça dois números e imprima a soma.

# %%
numero_1 = float(input("Informe o primeiro número: "))
numero_2 = float(input("Informe o segundo número: "))

soma = numero_1 + numero_2

print(f"A soma dos números informados: {soma}")
# Out:
# A soma dos números informados: 4.0

# %% [markdown]
# #### 4. Faça um Programa que peça as 4 notas bimestrais de um aluno e mostre a média de todas as notas.

# %%
nota_1 = float(input("Nota 1º Bimestre: "))
nota_2 = float(input("Nota 2º Bimestre: "))
nota_3 = float(input("Nota 3º Bimestre: "))
nota_4 = float(input("Nota 4º Bimestre: "))

soma_notas = nota_1 + nota_2 + nota_3 + nota_4
media_notas = soma_notas / 4

print(f"A médias das notas: {media_notas}")
# Out:
# A médias das notas: 4.75

# %% [markdown]
# #### 5. Faça um Programa que converta metros para centímetros. Você pode pedir o comprimento em metros para o usuário (input).

# %%
metros = float(input("Informa o comprimento em metros: "))

centimetro = metros * 100

print(f"O comprimento em centímetros: {centimetro}cm.")
# Out:
# O comprimento em centímetros: 200cm.

# %% [markdown]
# #### 6. Faça um Programa que calcule a área de uma sala de um apartamento. Para isso, o seu programa precisa pedir a largura da sala, o comprimento da sala e imprimir a área em m² da sala.

# %%
largura = float(input("Qual é a largura da sala?"))
comprimento = int(input("Qual é o comprimento da sala?"))

area = largura * comprimento

print(f"A área da sala é de {area}m2.")
# Out:
# A área da sala é de 4m2.

# %% [markdown]
# #### 7. Faça um Programa que pergunte quanto você ganha por hora e o número de horas trabalhadas no mês. Calcule e mostre o total do seu salário no referido mês.

# %%
ganho_hora = float(input("Quanto você ganha por hora trabalhada?"))
horas_mes = int(input("Quantas horas você trabalha no mês?"))

salario_mes = ganho_hora * horas_mes

print(f"Total de seu salário no mês: {salario_mes}")
# Out:
# Total de seu salário no mês: 4000

# %% [markdown]
# #### 8. Vamos criar um conversor de temperatura. Faça um Programa que peça a temperatura em graus Fahrenheit, transforme e mostre a temperatura em graus Celsius.
# $C = \frac{5}{9}(F-32)$

# %%
fahrenheit = float(input("Temperatura em graus Fahrenheit: "))

celsius = (5 / 9) * (fahrenheit - 32)

print(f"A temperatura em graus Celsius: {celsius}.")
# Out:
# A temperatura em graus Celsius: 37.77777777777778.

# %% [markdown]
# #### 9. Faça um Programa que peça a temperatura em graus Celsius, transforme e mostre em graus Fahrenheit.
# $F = \frac{9}{5}C + 32$

# %%
celsius = float(input("Temperatura em graus Celsius: "))

fahrenheit = (9 / 5) * celsius + 32

print(f"A temperatura em graus Fahrenheit: {fahrenheit}.")
# Out:
# A temperatura em graus Fahrenheit: 100.4.

# %% [markdown]
# #### 10. Tendo como dados de entrada a altura (h) de uma pessoa, construa um algoritmo que calcule seu peso ideal, usando a seguinte fórmula:
# $P = 72,7h - 58$
#
# Lembrando que "algoritmo" nada mais é do que um programa, como todos os outros que você vem fazendo

# %%
altura = float(input("Qual é a sua altura?"))

peso = 72.7 * altura - 58

print(f"Seu peso ideal é de {peso}kg.")
# Out:
# Seu peso ideal é de 53.23100000000001kg.

# %% [markdown]
# #### 11. Tendo como dado de entrada a altura (h) de uma pessoa, construa um algoritmo que calcule seu peso ideal, utilizando as seguintes fórmulas:
# ##### a. Para homens: $P = 72,7h - 58$
# ##### b. Para mulheres: $P = 62,1h - 44,7$

# %%
altura = float(input("Qual é a sua altura?"))
genero = input("Qual é o seu gênero? (Homem/Mulher)")

if genero == "homem":
    peso = 72.7 * altura - 58
else:
    peso = 62.1 * altura - 44.7

print(f"Seu peso ideial é de {peso}kg.")
# Out:
# Seu peso ideial é de 50.313kg.

# %% [markdown]
# #### 12. Faça um Programa que pergunte quanto você ganha por hora e o número de horas trabalhadas no mês.

# %%
ganho_hora = float(input("Quanto você ganha por hora trabalhada?"))
horas_mes = int(input("Quantas horas você trabalha no mês?"))

# %% [markdown]
# #####  Calcule o salário bruto (horas * salario por hora)

# %%
salario_bruto = ganho_hora * horas_mes

# %% [markdown]
# ##### Calcule o desconto do IR (11% do salário bruto)

# %%
desconto_ir = salario_bruto * 0.11

# %% [markdown]
# ##### Calcule o desconto do INSS (8% do salário bruto)

# %%
desconto_inss = salario_bruto * 0.08

# %% [markdown]
# ##### Calcule o desconto do sindicato (5% do salário bruto)

# %%
desconto_sindicato = salario_bruto * 0.05

# %% [markdown]
# ##### Calcule o salário líquido (salário bruto - descontos)

# %%
salario_liquido = salario_bruto - desconto_inss - desconto_sindicato - desconto_ir

print(salario_liquido)
# Out:
# 3040.0

# %% [markdown]
# #### 13. Faça um programa para uma loja de tintas. O programa deverá pedir o tamanho em metros quadrados da área a ser pintada. Considere que a cobertura da tinta é de 1 litro para cada 3 metros quadrados e que a tinta é vendida em latas de 18 litros, que custam R\$ 80,00. Informe ao usuário a quantidades de latas de tinta a serem compradas e o preço total. (para simplificação nesse momento, não se preocupe em arredondar a quantidade de latas a serem compradas - vamos trabalhar isso em breve)

# %%
area = float(input('Informe o tamanho da área a ser pintada em m²: '))

litros_tinta = area / 3 
latas = litros_tinta / 18
preco = latas * 80

print(f'Serão necessárias {latas} latas, custando R$ {preco} no total')
# Out:
# Serão necessárias 3.703703703703704 latas, custando R$ 296.2962962962963 no total

# %% [markdown]
# #### 14. Faça um programa que peça o tamanho de um arquivo para download (em MB) e a velocidade de um link de Internet (em Mbps), calcule e informe o tempo aproximado de download do arquivo usando este link (em minutos).
#
# Detalhe: MB significa megabyte, Mb (com b minúsculo) significa megabit. Um megabit é 1/8 de um megabyte.

# %%
tamanho = float(input('Informe o tamanho do arquivo em MB: '))
velocidade = float(input('Informe a velocidade da conexão em Mbps: '))

# aqui trasnformamos megabytes em megabits para que tamanho e velocidade estejam na mesma unidade
tamanho_megabits = tamanho * 8

tempo = tamanho_megabits / velocidade

# transformando em minutos
tempo_minutos = tempo / 60

print(f'O tempo de download é de {tempo_minutos} minutos')
# Out:
# O tempo de download é de 0.0026666666666666666 minutos
